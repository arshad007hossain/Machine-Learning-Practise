# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('homeprices.csv')
df
# Out:
#    area  price
# 0  2600  55000
# 1  3000  56500
# 2  3200  61000
# 3  3600  68000
# 4  4000  72000
# 5  5000  90000
# 6  2500  40000
# 7  2700  45000
# 8  1200  20000
# 9  5200  95000

# %%
x = df[['area']]
y = df['price']

# %%
#Visualization

plt.scatter(df['area'],df['price'], marker='+', color='red')
plt.xlabel('Area in square feet')
plt.ylabel('Prices in taka')
plt.title('Homeprices in Dhaka')
# Out:
# C:\Users\AL SAFAR PC2\anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size = .30, random_state = 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(xtrain.values,ytrain.values)
# Out:
# LinearRegression()

# %%
reg.predict(xtest.values)
# Out:
# array([58848.94632861, 95133.10833059, 46149.48962792])

# %%
plt.scatter(df['area'],df['price'], marker='+', color='red')
plt.xlabel('Area in square feet')
plt.ylabel('Prices in taka')
plt.title('Homeprices in Dhaka')
plt.plot(df.area, reg.predict(df[['area']]))
# Out:
# C:\Users\AL SAFAR PC2\anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
reg.predict([[3900]])
# Out:
# array([71548.40302931])

# %%
# y = mx + c
reg.coef_
# Out:
# array([18.142081])

# %%
reg.intercept_
# Out:
# 794.2871254527199

# %%
 y = 18.142081 * 3900 + 794.2871254527199

# %%
y
# Out:
# 71548.40302545272
